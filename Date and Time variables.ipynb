# %% [markdown]
# <a href="https://colab.research.google.com/github/GVAmit/ML-notes/blob/main/Date%20and%20Time%20variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.sample(5)
# Out:
#                     date                                                msg
# 835  2014-10-31 23:56:00      парень ищет не скромную девушку 063 410 64 82
# 977  2013-08-21 23:33:00  МУЖЧИНА 40 ПОЗНАКОМЛЮСЬ С СЕМЕЙНОЙ ПАРОЙ 09339...
# 452  2012-09-30 00:04:00  2 парня 20-23г. Ждут девушек в гости. 38093705...
# 397  2014-02-06 01:53:00        М 47 неглупый одинокий познакомлюсь для с/о
# 182  2014-06-30 23:33:00  Просто пообщаюсь с приятной девушкой.Дима 21 г...

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
date['date_year'] = date['date'].dt.year

date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019

# %%
date['date_month_no'] = date['date'].dt.month

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#    date_month_no  date_day date_month_name
# 0             12        10        December
# 1              8        15          August
# 2             10        23         October
# 3              8        17          August
# 4              1         6         January

# %%
date['date_month_name'] = date['date'].dt.month_name()

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#    date_month_no  date_day date_month_name
# 0             12        10        December
# 1              8        15          August
# 2             10        23         October
# 3              8        17          August
# 4              1         6         January

# %%
date['date_day'] = date['date'].dt.day

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#    date_month_no  date_day
# 0             12        10
# 1              8        15
# 2             10        23
# 3              8        17
# 4              1         6

# %%
date['date_dow'] = date['date'].dt.dayofweek

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#    date_month_no  date_day date_month_name  date_dow
# 0             12        10        December         1
# 1              8        15          August         2
# 2             10        23         October         1
# 3              8        17          August         5
# 4              1         6         January         6

# %%
date['date_dow_name'] = date['date'].dt.day_name()

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no  date_day date_month_name  \
# 0 2019-12-10       2019          12             12        10        December
# 1 2018-08-15       2018           8              8        15          August
# 2 2018-10-23       2018          10             10        23         October
# 3 2019-08-17       2019           8              8        17          August
# 4 2019-01-06       2019           1              1         6         January
#
#    date_dow date_dow_name
# 0         1       Tuesday
# 1         2     Wednesday
# 2         1       Tuesday
# 3         5      Saturday
# 4         6        Sunday

# %%
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no  date_day date_month_name  \
# 0 2019-12-10       2019          12             12        10        December
# 1 2018-08-15       2018           8              8        15          August
# 2 2018-10-23       2018          10             10        23         October
# 3 2019-08-17       2019           8              8        17          August
# 4 2019-01-06       2019           1              1         6         January
#
#    date_dow date_dow_name  date_is_weekend
# 0         1       Tuesday                0
# 1         2     Wednesday                0
# 2         1       Tuesday                0
# 3         5      Saturday                1
# 4         6        Sunday                1

# %%
date['date_week'] = date['date'].dt.isocalendar().week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no  date_day date_month_name  \
# 0 2019-12-10       2019          12             12        10        December
# 1 2018-08-15       2018           8              8        15          August
# 2 2018-10-23       2018          10             10        23         October
# 3 2019-08-17       2019           8              8        17          August
# 4 2019-01-06       2019           1              1         6         January
#
#    date_dow date_dow_name  date_is_weekend  date_week
# 0         1       Tuesday                0         50
# 1         2     Wednesday                0         33
# 2         1       Tuesday                0         43
# 3         5      Saturday                1         33
# 4         6        Sunday                1          1

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no  date_day date_month_name  \
# 0 2019-12-10       2019          12             12        10        December
# 1 2018-08-15       2018           8              8        15          August
# 2 2018-10-23       2018          10             10        23         October
# 3 2019-08-17       2019           8              8        17          August
# 4 2019-01-06       2019           1              1         6         January
#
#    date_dow date_dow_name  date_is_weekend  date_week  quarter
# 0         1       Tuesday                0         50        4
# 1         2     Wednesday                0         33        3
# 2         1       Tuesday                0         43        4
# 3         5      Saturday                1         33        3
# 4         6        Sunday                1          1        1

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no  date_day date_month_name  \
# 0 2019-12-10       2019          12             12        10        December
# 1 2018-08-15       2018           8              8        15          August
# 2 2018-10-23       2018          10             10        23         October
# 3 2019-08-17       2019           8              8        17          August
# 4 2019-01-06       2019           1              1         6         January
#
#    date_dow date_dow_name  date_is_weekend  date_week  quarter  semester
# 0         1       Tuesday                0         50        4         2
# 1         2     Wednesday                0         33        3         2
# 2         1       Tuesday                0         43        4         2
# 3         5      Saturday                1         33        3         2
# 4         6        Sunday                1          1        1         1

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2025, 9, 13, 12, 45, 56, 426451)

# %%
today - date['date']
# Out:
# 0     2104 days 12:45:56.426451
# 1     2586 days 12:45:56.426451
# 2     2517 days 12:45:56.426451
# 3     2219 days 12:45:56.426451
# 4     2442 days 12:45:56.426451
#                  ...
# 995   2532 days 12:45:56.426451
# 996   2473 days 12:45:56.426451
# 997   2321 days 12:45:56.426451
# 998   2386 days 12:45:56.426451
# 999   2160 days 12:45:56.426451
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2104
# 1      2586
# 2      2517
# 3      2219
# 4      2442
#        ...
# 995    2532
# 996    2473
# 997    2321
# 998    2386
# 999    2160
# Name: date, Length: 1000, dtype: int64

# %%
np.round((today - date['date']) / np.timedelta64(1, 'm'), 0)
# Out:
# 0      3030526.0
# 1      3724606.0
# 2      3625246.0
# 3      3196126.0
# 4      3517246.0
#          ...
# 995    3646846.0
# 996    3561886.0
# 997    3343006.0
# 998    3436606.0
# 999    3111166.0
# Name: date, Length: 1000, dtype: float64

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB
